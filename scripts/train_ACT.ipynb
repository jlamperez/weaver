# %% [markdown]
# # LeRobot Train Notebooks
#
# This Notebook is based on:
#
# - https://huggingface.co/docs/lerobot/notebooks

# %%
import torch
print(f'CUDA compatible device availability:',torch.cuda.is_available())
print(f'device name [0]:', torch.cuda.get_device_name(0))
# Out:
# CUDA compatible device availability: True
# device name [0]: Tesla T4

# %% [markdown]
# ## Install FFMPEG

# %%
# !add-apt-repository ppa:ubuntuhandbook1/ffmpeg7 -y # install PPA which contains ffmpeg 7.x
# !apt update && apt install ffmpeg -y
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu/ jammy main'
# Description:
# unofficial build for FFmpeg 7 for Ubuntu 22.04 | 24.04, backport from Debian's deb.multimedia.org repository
#
# If the packages here are helpful, you may buy me a coffee:
#
#          https://ko-fi.com/ubuntuhandbook1
# More info: https://launchpad.net/~ubuntuhandbook1/+archive/ubuntu/ffmpeg7
# Adding repository.
# Found existing deb entry in /etc/apt/sources.list.d/ubuntuhandbook1-ubuntu-ffmpeg7-jammy.list
# Adding deb entry to /etc/apt/sources.list.d/ubuntuhandbook1-ubuntu-ffmpeg7-jammy.list
# Found existing deb-src entry in /etc/apt/sources.list.d/ubuntuhandbook1-ubuntu-ffmpeg7-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/ubuntuhandbook1-ubuntu-ffmpeg7-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/ubuntuhandbook1-ubuntu-ffmpeg7.gpg with fingerprint F4E48910A020E77056748B745738AE8480447DDF
# ...

# %% [markdown]
# ## Install LeRobot

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !cd lerobot && pip install -e .
# Out:
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.3-0.editable-py3-none-any.whl size=12152 sha256=6d1ac71c3e1274735987ad7b0717eecfd3d85bb67016ef63a5c79bd1ef15b89d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-codnwrk9/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
# Successfully built lerobot
# ...
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.3
#     Uninstalling lerobot-0.4.3:
#       Successfully uninstalled lerobot-0.4.3
# ...

# %%
# !ls -la
# Out:
# total 24
# drwxr-xr-x  1 root root 4096 Dec 25 12:25 .
# drwxr-xr-x  1 root root 4096 Dec 25 11:33 ..
# drwxr-xr-x  4 root root 4096 Dec  9 14:41 .config
# drwxr-xr-x 11 root root 4096 Dec 25 11:57 lerobot
# drwxr-xr-x  3 root root 4096 Dec 25 12:25 outputs
# drwxr-xr-x  1 root root 4096 Dec  9 14:42 sample_data

# %% [markdown]
# ## PASSWORDS

# %%
WAND_API_KEY= "X"
HF_TOKEN = "X"

# %% [markdown]
# ## Weights & Biases login

# %%
import wandb
wandb.login(key=WAND_API_KEY)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %% [markdown]
# ## Login into Hugging Face Hub

# %%
from huggingface_hub import login
login(token=HF_TOKEN)

# %% [markdown]
# ## Start Training Models with LeRobot

# %%
# !lerobot-train \
  --dataset.repo_id="jlamperez/weaver-so101-pick-orange" \
  --policy.type=act \
  --policy.repo_id="jlamperez/weaver-so101-act-pick-orange-policy" \
  --batch_size=16 \
  --num_workers=2 \
  --steps=5000 \
  --save_freq=2500 \
  --output_dir="outputs/train/weaver-so101-pick-orange-test0" \
  --job_name="weaver-so101-pick-orange-test0" \
  --policy.device=cuda \
  --wandb.enable=true \
  --policy.use_amp=true\
  --log_freq=100 \
  --policy.push_to_hub=True
# Out:
# 2025-12-25 14:28:32.080992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766672912.105654   52119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766672912.115907   52119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766672912.135787   52119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls ~/.cache/huggingface

# %%
# !rm -rf outputs/train/weaver-so101-pick-orange-test0
